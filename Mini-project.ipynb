# %% [markdown]
# # Pitch Shifting Voice Effects

# %% [markdown]
# # Abstract

# %% [markdown]
# # Introduction

# %% [markdown]
# # Existing techniques

# %% [markdown]
# # Algorithm description

# %% [markdown]
# # Results and discussion

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Bibliography
